# %% [markdown]
# <img src="https://theaiengineer.dev/tae_logo_gw_flatter.png" width=35% align=right>

# %% [markdown]
# # AI Agents & Automation — Chapter 4
# ## Language Models as Agent Brains
#
# &copy; Dr. Yves J. Hilpisch<br>
# AI-Powered by GPT-5.

# %% [markdown]
# ### Overview
#
# This notebook accompanies Chapter 4 — Llms Planning. It is self-contained and demonstrates the core ideas with small, readable code cells. Run cells from top to bottom; each code cell is preceded by a short explanation of what it does.

# %% [markdown]
# We simulate a planner stub that returns a short, tool-ready plan and a validator that catches common issues.

# %%
def fake_llm_plan(prompt: str): # define function fake_llm_plan()
    return ["parse_numbers", "compute_sum", "report_result"] # return value

def validate(steps): # define function validate()
    assert len(steps)==3, 'need exactly 3 steps' # step
    for s in steps: assert isinstance(s, str) and s, 'empty step' # loop over items

plan = fake_llm_plan('add 2 and 3') # set plan
validate(plan) # call validate()
print(plan) # print output

# %% [markdown]
# Replace the stub with your model call later; keep the same contract so the validator and executor remain unchanged.

# %% [markdown]
# <img src="https://theaiengineer.dev/tae_logo_gw_flatter.png" width=35% align=right>
